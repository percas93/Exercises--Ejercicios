# %%
nmbr = "MCMXCIII"

# %%
mapping = {"M": 1000, "D": 500, "C": 100, "L": 50, "X": 10, "I": 1}

# %%
def findNum(string):
    mapping.get(x, x) for x in nmbr

# %%
normalMapping = [mapping.get(x, x) for x in nmbr]
normalMapping
# Out:
# [1000, 100, 1000, 10, 100, 1, 1, 1]
