# %%
nmbr = "MCMXCIII"

# %%
mapping = {"M": 1000, "D": 500, "C": 100, "L": 50, "X": 10, "I": 1}

# %%
def findNum(string):
    
    # PREPARING THE INPUT
    string = string.upper()
    mapping = {"M": 1000, "D": 500, "C": 100, "L": 50, "X": 10, "V":5, "I": 1}
    intList = [mapping.get(x, 0) for x in string]
    # print(intList)

    # VALIDATING THE INPUT
    for ch in string:
        if ch not in mapping:
            return f"{string} is an invalid Roman Number"
            # raise ValueError(f"{string} is an invalid Roman Number")
        

    # PARSING IT INTO AN INTEGER
    for i in range(len(intList)-1):
        if intList[i] < intList[i+1]:
            intList[i] = intList[i] * (-1)
        # print(i, intList[i])

    return sum(intList)

# %%
findNum("mmo")
# Out:
# 'MMO is an invalid Roman Number'

# %%
findNum("MCMXCIX")
# Out:
# 1999

# %%
findNum("mmiv")
# Out:
# 2004

# %%
findNum(nmbr)
# Out:
# 1993

# %%
normalMapping = [mapping.get(x, x) for x in nmbr]
normalMapping
# Out:
# [1000, 100, 1000, 10, 100, 1, 1, 1]
