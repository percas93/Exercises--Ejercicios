# %% [markdown]
# # 3 Sum
#
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.
#
# Notice that the solution set must not contain duplicate triplets.
#
#
# <br><br>
#
# ***

# %% [markdown]
# ## Example:
#
# ### Example 1:
#
# >Input: nums = [-1,0,1,2,-1,-4]<br>
# >Output: [[-1,-1,2],[-1,0,1]]<br>
# >
# >Explanation: <br>
# >nums[0] + nums[1] + nums[2] = (-1) + 0 + 1 = 0.<br>
# >nums[1] + nums[2] + nums[4] = 0 + 1 + (-1) = 0.<br>
# >nums[0] + nums[3] + nums[4] = (-1) + 2 + (-1) = 0.<br>
# >
# >The distinct triplets are [-1,0,1] and [-1,-1,2].<br>
# >Notice that the order of the output and the order of the triplets does not matter.<br>
#
# ### Example 2:
#
# >Input: nums = [0,1,1]<br>
# >Output: []<br>
# >Explanation: The only possible triplet does not sum up to 0.
#
# ### Example 3:
#
# >Input: nums = [0,0,0]<br>
# >Output: [[0,0,0]]<br>
# >Explanation: The only possible triplet sums up to 0.
#
# <br>
# <br>
#
# ***

# %% [markdown]
# # Final Solution
#
# I'm happy with this solution. I think I did a good job here.<br>

# %%
nums = [-1,0,1,2,-1,-4]

# %%
def threeSum(givenArray):

    result = []
    woZero = [x for x in givenArray if x != 0]

    # Triplets with Zero:
    if 0 in givenArray:
        for y in woZero:
            if y * (-1) in woZero:
                triplet = [(y * (-1)), 0, y]
                triplet.sort()
                if triplet not in result:
                    result.append(triplet)

    # Other triplets:
    i = 0
    ii = 0
    while i < len(woZero):
        a = woZero[i]
        while ii < len(woZero):
            if i == ii:
                break
            else:
                b = woZero[ii]
                num2Find = (a + b) * (-1)
                if num2Find in woZero:
                    c = num2Find
                    triplet = [a,b,c]
                    triplet.sort()
                    if triplet not in result:
                        result.append(triplet)
            ii += 1

        i += 1

    # Triplet [0,0,0]:
    if givenArray.count(0) >= 3:
        result.append([0,0,0])

    
    
    return result

# %%
threeSum(nums)
# Out:
# [[-1, 0, 1], [-1, -1, 2]]

# %%
threeSum([0,1,1])
# Out:
# []

# %%
threeSum([0,0,0])
# Out:
# [[0, 0, 0]]

# %%
threeSum([])
# Out:
# []

# %%
threeSum([1,2])
# Out:
# []
